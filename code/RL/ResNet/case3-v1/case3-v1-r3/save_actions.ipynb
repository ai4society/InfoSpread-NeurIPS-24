# %%
import torch
import numpy as np
import pickle as pkl
from glob import glob
import os
import argparse
import regex as re
import pandas as pd
import statistics
import copy

from MisInfoSpread import MisInfoSpread
from MisInfoSpread import MisInfoSpreadState

def flatten(state):
    return [val * i for val, adj in zip(state.node_states, state.adjacency_matrix) for i in adj]

# %%
def run_inference( dataset_path, model_path, nodes, max_steps, st, count_inf, count_actions):
    
    # device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
    print(f"Using device: {device}")

    misinfo = MisInfoSpread(num_nodes=nodes, max_time_steps=max_steps, 
                        trust_on_source=st, count_infected_nodes=count_inf, 
                        count_actions=count_actions)

    model = misinfo.get_nnet_model().to(device)
    model.load_state_dict(torch.load(model_path , map_location=torch.device(device)))

    states = pkl.load(open(dataset_path, 'rb'))
    # for state in states:
    #     state.node_states = [int(x) for x in state.node_states]
    #     for i in range(len(state.adjacency_matrix)):
    #         for j in range(len(state.adjacency_matrix[i])):
    #             if state.adjacency_matrix[i][j] != 0:
    #                 state.adjacency_matrix[i][j] = 1
    #             else:
    #                 state.adjacency_matrix[i][j] = 0

    candidate_nodes = misinfo.find_neighbor_batch(states)

    actions_dict = {i: {'actions': [], 'infRate': 0} for i in range(len(states))}

    while any(candidate_node for candidate_node in candidate_nodes):
        blockernode_np = []
        count = 0
        for state, cand_nodes in zip(states, candidate_nodes):
            print("Processing states ", count, end='\r')
            if cand_nodes:
                expectation_values = []
                for cand_node in cand_nodes:
                    temp_ns, _, _ = misinfo.step(copy.deepcopy(state), [cand_node])
                    output_tensor = torch.FloatTensor(flatten(temp_ns)).view(1, -1).to(device)
                    expected_infection = model(output_tensor).detach().cpu().numpy()
                    expectation_values.append( (expected_infection, cand_node) )

                # sort the expectation values based on the expected infection
                expectation_values.sort(key=lambda x: x[0], reverse=True)

                if len(expectation_values) < count_actions:
                    blockernode_np.append([node for _, node in expectation_values])
                    actions_dict[count]['actions'].append([node for _, node in expectation_values])
                else:
                    blockernode_np.append([node for _, node in expectation_values[:count_actions]])
                    actions_dict[count]['actions'].append([node for _, node in expectation_values[:count_actions]])
            else:
                blockernode_np.append([])

            count += 1
        next_states, rewards, done = misinfo.step_batch(states, blockernode_np)
        states = next_states
        candidate_nodes = misinfo.find_neighbor_batch(states)
        # print count of dones
        print("Done: ", done.count(True), " "*20)
        if all(done):
            break
    
    inf_rate = []
    count = 0
    for state in states:
        inf_rate.append(state.node_states.count(-1.0)/len(state.node_states))
        actions_dict[count]['infRate'] = state.node_states.count(-1.0)/len(state.node_states)
        count += 1

    mean = round(statistics.mean(inf_rate), 4)
    std_dev = round(statistics.stdev(inf_rate), 4)
    print(f"Mean: {mean}, Std Dev: {std_dev}")
    return mean, std_dev, actions_dict

# %%
model = "saved_models/target_model_1_1_mn10_ms100_st1.0.pt"
dataset_path = "/Users/bittu/Desktop/InfoSpread-server/dataset/generate_dataset/deg_dataset/10/10_deg_3.pkl"

mean, std_dev, actions_dict = run_inference(dataset_path, model, 10, 50, 1.0, 1, 1)
# Out:
# Using device: mps
# Done:  0
# Done:  25
# Done:  984
# Done: sing states  999 997
# Done:  1000
# Mean: 0.2096, Std Dev: 0.0872

# %%
for key, item in actions_dict.items():
    if len(item['actions']) < 3 and len(item['actions']) > 1:
        print(key, item['actions'], item['infRate'])
# Out:
# 14 [9, 7] 0.3
# 31 [6, 5] 0.3
# 37 [6, 8] 0.4
# 61 [9, 4] 0.3
# 113 [5, 9] 0.4
# 120 [3, 6] 0.4
# 176 [4, 6] 0.3
# 179 [8, 2] 0.2
# 231 [9, 7] 0.2
# 233 [9, 5] 0.3
# 242 [7, 0] 0.2
# 354 [1, 3] 0.3
# 400 [9, 0] 0.3
# 427 [4, 9] 0.3
# 476 [5, 0] 0.2
# 505 [9, 7] 0.3
# 528 [8, 5] 0.4
# 606 [4, 7] 0.4
# 612 [1, 6] 0.2
# 688 [0, 1] 0.4
# 805 [6, 1] 0.2
# 822 [3, 0] 0.3
# 871 [5, 8] 0.2
# 902 [3, 0] 0.4
# 937 [5, 7] 0.4

# %%
actions_dict
# Out:
# {0: {'actions': [[3], [0], [7]], 'infRate': 0.2},
#  1: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  2: {'actions': [[0], [5], [3]], 'infRate': 0.1},
#  3: {'actions': [[0], [6], [7]], 'infRate': 0.3},
#  4: {'actions': [[9], [6], [4]], 'infRate': 0.1},
#  5: {'actions': [[3], [4], [8]], 'infRate': 0.2},
#  6: {'actions': [[9], [1], [7]], 'infRate': 0.2},
#  7: {'actions': [[4], [9], [1]], 'infRate': 0.3},
#  8: {'actions': [[4], [6], [5]], 'infRate': 0.2},
#  9: {'actions': [[6], [8], [1]], 'infRate': 0.2},
#  10: {'actions': [[4], [7], [9]], 'infRate': 0.2},
#  11: {'actions': [[4], [3], [6]], 'infRate': 0.2},
#  12: {'actions': [[5], [4], [1]], 'infRate': 0.2},
#  13: {'actions': [[9], [1], [6]], 'infRate': 0.1},
#  14: {'actions': [[9], [7]], 'infRate': 0.3},
#  15: {'actions': [[9], [1], [4]], 'infRate': 0.3},
#  16: {'actions': [[1], [8], [4]], 'infRate': 0.2},
#  17: {'actions': [[4], [3], [8]], 'infRate': 0.1},
#  18: {'actions': [[2], [7], [4]], 'infRate': 0.2},
#  19: {'actions': [[1], [4], [2]], 'infRate': 0.1},
#  20: {'actions': [[8], [9], [6]], 'infRate': 0.1},
#  21: {'actions': [[5], [1], [2]], 'infRate': 0.1},
#  22: {'actions': [[4], [1], [7]], 'infRate': 0.3},
#  23: {'actions': [[3], [6], [8]], 'infRate': 0.1},
#  24: {'actions': [[5], [9], [8]], 'infRate': 0.2},
#  25: {'actions': [[4], [8], [6]], 'infRate': 0.3},
#  26: {'actions': [[5], [2], [8]], 'infRate': 0.3},
#  27: {'actions': [[7], [5], [2]], 'infRate': 0.1},
#  28: {'actions': [[8], [6], [3]], 'infRate': 0.2},
#  29: {'actions': [[2], [1], [5]], 'infRate': 0.3},
#  30: {'actions': [[1], [7], [3]], 'infRate': 0.2},
#  31: {'actions': [[6], [5]], 'infRate': 0.3},
#  32: {'actions': [[3], [6], [7]], 'infRate': 0.2},
#  33: {'actions': [[4], [9], [1]], 'infRate': 0.2},
#  34: {'actions': [[0], [3], [5]], 'infRate': 0.3},
#  35: {'actions': [[2], [4], [6]], 'infRate': 0.1},
#  36: {'actions': [[0], [3], [7]], 'infRate': 0.3},
#  37: {'actions': [[6], [8]], 'infRate': 0.4},
#  38: {'actions': [[0], [6], [4]], 'infRate': 0.3},
#  39: {'actions': [[2], [1], [5]], 'infRate': 0.3},
#  40: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  41: {'actions': [[4], [9], [8]], 'infRate': 0.3},
#  42: {'actions': [[3], [2], [5]], 'infRate': 0.1},
#  43: {'actions': [[9], [3], [7]], 'infRate': 0.3},
#  44: {'actions': [[3], [9], [2]], 'infRate': 0.3},
#  45: {'actions': [[0], [8], [7]], 'infRate': 0.1},
#  46: {'actions': [[0], [7], [5]], 'infRate': 0.3},
#  47: {'actions': [[2], [4], [5]], 'infRate': 0.3},
#  48: {'actions': [[6], [4], [9]], 'infRate': 0.3},
#  49: {'actions': [[0], [7], [2]], 'infRate': 0.2},
#  50: {'actions': [[9], [3], [8]], 'infRate': 0.1},
#  51: {'actions': [[3], [0], [8]], 'infRate': 0.2},
#  52: {'actions': [[9], [0], [7]], 'infRate': 0.1},
#  53: {'actions': [[7], [4], [2]], 'infRate': 0.1},
#  54: {'actions': [[9], [1], [7]], 'infRate': 0.2},
#  55: {'actions': [[0], [9], [7]], 'infRate': 0.2},
#  56: {'actions': [[6], [9], [3]], 'infRate': 0.3},
#  57: {'actions': [[5], [7], [3]], 'infRate': 0.3},
#  58: {'actions': [[3], [1], [5]], 'infRate': 0.1},
#  59: {'actions': [[5], [1], [8]], 'infRate': 0.2},
#  60: {'actions': [[9], [1], [8]], 'infRate': 0.2},
#  61: {'actions': [[9], [4]], 'infRate': 0.3},
#  62: {'actions': [[4], [2], [1]], 'infRate': 0.1},
#  63: {'actions': [[6], [8], [1]], 'infRate': 0.1},
#  64: {'actions': [[5], [9], [3]], 'infRate': 0.2},
#  65: {'actions': [[9], [8], [2]], 'infRate': 0.2},
#  66: {'actions': [[0], [6], [2]], 'infRate': 0.2},
#  67: {'actions': [[5], [3], [0]], 'infRate': 0.3},
#  68: {'actions': [[9], [8], [4]], 'infRate': 0.4},
#  69: {'actions': [[6], [0], [3]], 'infRate': 0.3},
#  70: {'actions': [[6], [0], [8]], 'infRate': 0.2},
#  71: {'actions': [[4], [8], [2]], 'infRate': 0.1},
#  72: {'actions': [[4], [9], [6]], 'infRate': 0.3},
#  73: {'actions': [[4], [0], [7]], 'infRate': 0.1},
#  74: {'actions': [[7], [3], [9]], 'infRate': 0.2},
#  75: {'actions': [[2], [0], [6]], 'infRate': 0.2},
#  76: {'actions': [[5], [1], [7]], 'infRate': 0.1},
#  77: {'actions': [[5], [4], [7]], 'infRate': 0.1},
#  78: {'actions': [[3], [6], [7]], 'infRate': 0.2},
#  79: {'actions': [[3], [9], [1]], 'infRate': 0.2},
#  80: {'actions': [[3], [5], [0], [6]], 'infRate': 0.3},
#  81: {'actions': [[0], [4], [8]], 'infRate': 0.3},
#  82: {'actions': [[6], [5], [1]], 'infRate': 0.1},
#  83: {'actions': [[3], [6], [8]], 'infRate': 0.3},
#  84: {'actions': [[0], [7], [6]], 'infRate': 0.2},
#  85: {'actions': [[3], [2], [8]], 'infRate': 0.1},
#  86: {'actions': [[9], [6], [3]], 'infRate': 0.3},
#  87: {'actions': [[1], [6], [5]], 'infRate': 0.2},
#  88: {'actions': [[4], [8], [5]], 'infRate': 0.1},
#  89: {'actions': [[7], [5], [9]], 'infRate': 0.1},
#  90: {'actions': [[6], [4], [1]], 'infRate': 0.1},
#  91: {'actions': [[5], [3], [1]], 'infRate': 0.2},
#  92: {'actions': [[9], [4], [7]], 'infRate': 0.3},
#  93: {'actions': [[3], [9], [1]], 'infRate': 0.1},
#  94: {'actions': [[0], [7], [2]], 'infRate': 0.3},
#  95: {'actions': [[3], [1], [5], [7]], 'infRate': 0.2},
#  96: {'actions': [[3], [8], [4]], 'infRate': 0.1},
#  97: {'actions': [[5], [3], [6]], 'infRate': 0.2},
#  98: {'actions': [[8], [5], [9]], 'infRate': 0.1},
#  99: {'actions': [[4], [7], [9]], 'infRate': 0.1},
#  100: {'actions': [[4], [5], [7]], 'infRate': 0.1},
#  101: {'actions': [[5], [9], [0]], 'infRate': 0.3},
#  102: {'actions': [[9], [2], [7]], 'infRate': 0.3},
#  103: {'actions': [[5], [1], [7]], 'infRate': 0.3},
#  104: {'actions': [[8], [1], [2]], 'infRate': 0.1},
#  105: {'actions': [[0], [1], [7]], 'infRate': 0.1},
#  106: {'actions': [[3], [1], [8]], 'infRate': 0.2},
#  107: {'actions': [[1], [9], [8]], 'infRate': 0.3},
#  108: {'actions': [[3], [9], [5]], 'infRate': 0.2},
#  109: {'actions': [[2], [8], [6]], 'infRate': 0.3},
#  110: {'actions': [[0], [7], [5]], 'infRate': 0.3},
#  111: {'actions': [[5], [2], [9]], 'infRate': 0.4},
#  112: {'actions': [[6], [1], [8]], 'infRate': 0.2},
#  113: {'actions': [[5], [9]], 'infRate': 0.4},
#  114: {'actions': [[4], [7], [2]], 'infRate': 0.1},
#  115: {'actions': [[5], [0], [8]], 'infRate': 0.4},
#  116: {'actions': [[7], [8], [4]], 'infRate': 0.2},
#  117: {'actions': [[3], [7], [0]], 'infRate': 0.4},
#  118: {'actions': [[9], [2], [6], [0]], 'infRate': 0.3},
#  119: {'actions': [[5], [1], [8]], 'infRate': 0.3},
#  120: {'actions': [[3], [6]], 'infRate': 0.4},
#  121: {'actions': [[8], [6], [4]], 'infRate': 0.3},
#  122: {'actions': [[9], [6], [4]], 'infRate': 0.1},
#  123: {'actions': [[3], [1], [0]], 'infRate': 0.3},
#  124: {'actions': [[1], [7], [3]], 'infRate': 0.2},
#  125: {'actions': [[7], [1], [5]], 'infRate': 0.1},
#  126: {'actions': [[9], [5], [2]], 'infRate': 0.3},
#  127: {'actions': [[3], [1], [8]], 'infRate': 0.2},
#  128: {'actions': [[8], [3], [6]], 'infRate': 0.1},
#  129: {'actions': [[2], [4], [6]], 'infRate': 0.1},
#  130: {'actions': [[0], [7], [3]], 'infRate': 0.4},
#  131: {'actions': [[1], [8], [6]], 'infRate': 0.1},
#  132: {'actions': [[7], [1], [8]], 'infRate': 0.2},
#  133: {'actions': [[9], [2], [0]], 'infRate': 0.1},
#  134: {'actions': [[8], [9], [7]], 'infRate': 0.3},
#  135: {'actions': [[4], [7], [2]], 'infRate': 0.3},
#  136: {'actions': [[5], [1], [0]], 'infRate': 0.1},
#  137: {'actions': [[6], [7], [5]], 'infRate': 0.3},
#  138: {'actions': [[1], [0], [7]], 'infRate': 0.1},
#  139: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  140: {'actions': [[3], [1], [4]], 'infRate': 0.3},
#  141: {'actions': [[4], [8], [2]], 'infRate': 0.2},
#  142: {'actions': [[3], [8], [9]], 'infRate': 0.1},
#  143: {'actions': [[5], [0], [3]], 'infRate': 0.1},
#  144: {'actions': [[7], [2], [8]], 'infRate': 0.3},
#  145: {'actions': [[9], [7], [2]], 'infRate': 0.2},
#  146: {'actions': [[3], [6], [0]], 'infRate': 0.1},
#  147: {'actions': [[8], [6], [4]], 'infRate': 0.1},
#  148: {'actions': [[0], [4], [1]], 'infRate': 0.2},
#  149: {'actions': [[3], [0], [4]], 'infRate': 0.3},
#  150: {'actions': [[5], [7], [9]], 'infRate': 0.1},
#  151: {'actions': [[4], [2], [1]], 'infRate': 0.3},
#  152: {'actions': [[4], [5], [0]], 'infRate': 0.2},
#  153: {'actions': [[1], [9], [8]], 'infRate': 0.3},
#  154: {'actions': [[2], [1], [6]], 'infRate': 0.1},
#  155: {'actions': [[3], [0], [4]], 'infRate': 0.3},
#  156: {'actions': [[3], [0], [1]], 'infRate': 0.3},
#  157: {'actions': [[3], [1], [8]], 'infRate': 0.1},
#  158: {'actions': [[5], [7], [3]], 'infRate': 0.2},
#  159: {'actions': [[9], [7], [1]], 'infRate': 0.2},
#  160: {'actions': [[8], [9], [5]], 'infRate': 0.1},
#  161: {'actions': [[0], [3], [8]], 'infRate': 0.3},
#  162: {'actions': [[0], [4], [1]], 'infRate': 0.1},
#  163: {'actions': [[5], [3], [2]], 'infRate': 0.1},
#  164: {'actions': [[1], [7], [9]], 'infRate': 0.1},
#  165: {'actions': [[0], [1], [9]], 'infRate': 0.3},
#  166: {'actions': [[3], [8], [5]], 'infRate': 0.1},
#  167: {'actions': [[7], [4], [2]], 'infRate': 0.2},
#  168: {'actions': [[8], [3], [1]], 'infRate': 0.3},
#  169: {'actions': [[3], [5], [7]], 'infRate': 0.2},
#  170: {'actions': [[2], [0], [4]], 'infRate': 0.2},
#  171: {'actions': [[5], [0], [2]], 'infRate': 0.3},
#  172: {'actions': [[9], [3], [2]], 'infRate': 0.1},
#  173: {'actions': [[8], [1], [2]], 'infRate': 0.3},
#  174: {'actions': [[3], [9], [1]], 'infRate': 0.3},
#  175: {'actions': [[1], [9], [6]], 'infRate': 0.1},
#  176: {'actions': [[4], [6]], 'infRate': 0.3},
#  177: {'actions': [[3], [7], [4]], 'infRate': 0.3},
#  178: {'actions': [[3], [4], [0]], 'infRate': 0.3},
#  179: {'actions': [[8], [2]], 'infRate': 0.2},
#  180: {'actions': [[4], [9], [7]], 'infRate': 0.3},
#  181: {'actions': [[5], [0], [2]], 'infRate': 0.1},
#  182: {'actions': [[8], [4], [6]], 'infRate': 0.3},
#  183: {'actions': [[2], [4], [5]], 'infRate': 0.3},
#  184: {'actions': [[2], [6], [8]], 'infRate': 0.1},
#  185: {'actions': [[5], [8], [2]], 'infRate': 0.2},
#  186: {'actions': [[3], [1], [7]], 'infRate': 0.3},
#  187: {'actions': [[6], [4], [8]], 'infRate': 0.2},
#  188: {'actions': [[3], [1], [5]], 'infRate': 0.1},
#  189: {'actions': [[4], [7], [1]], 'infRate': 0.3},
#  190: {'actions': [[5], [8], [3]], 'infRate': 0.3},
#  191: {'actions': [[7], [4], [2]], 'infRate': 0.1},
#  192: {'actions': [[0], [8], [1]], 'infRate': 0.3},
#  193: {'actions': [[7], [0], [3], [8], [2]], 'infRate': 0.4},
#  194: {'actions': [[5], [3], [7]], 'infRate': 0.3},
#  195: {'actions': [[2], [4], [1]], 'infRate': 0.2},
#  196: {'actions': [[8], [0], [6]], 'infRate': 0.1},
#  197: {'actions': [[3], [9], [7]], 'infRate': 0.3},
#  198: {'actions': [[0], [6], [7]], 'infRate': 0.3},
#  199: {'actions': [[7], [8], [0]], 'infRate': 0.2},
#  200: {'actions': [[4], [7], [1]], 'infRate': 0.3},
#  201: {'actions': [[5], [8], [0]], 'infRate': 0.1},
#  202: {'actions': [[3], [1], [0]], 'infRate': 0.2},
#  203: {'actions': [[5], [7], [3]], 'infRate': 0.2},
#  204: {'actions': [[5], [6], [1]], 'infRate': 0.2},
#  205: {'actions': [[8], [4], [0]], 'infRate': 0.4},
#  206: {'actions': [[2], [9], [7]], 'infRate': 0.3},
#  207: {'actions': [[4], [1], [8]], 'infRate': 0.3},
#  208: {'actions': [[6], [0], [3]], 'infRate': 0.2},
#  209: {'actions': [[9], [2], [5]], 'infRate': 0.2},
#  210: {'actions': [[6], [3], [5]], 'infRate': 0.3},
#  211: {'actions': [[5], [1], [7]], 'infRate': 0.3},
#  212: {'actions': [[2], [0], [8]], 'infRate': 0.2},
#  213: {'actions': [[6], [7], [4]], 'infRate': 0.3},
#  214: {'actions': [[1], [6], [2]], 'infRate': 0.2},
#  215: {'actions': [[0], [3], [1]], 'infRate': 0.1},
#  216: {'actions': [[4], [0], [2]], 'infRate': 0.2},
#  217: {'actions': [[2], [1], [6]], 'infRate': 0.3},
#  218: {'actions': [[0], [5], [2]], 'infRate': 0.3},
#  219: {'actions': [[3], [1], [6]], 'infRate': 0.1},
#  220: {'actions': [[5], [9], [2]], 'infRate': 0.3},
#  221: {'actions': [[4], [2], [0]], 'infRate': 0.3},
#  222: {'actions': [[4], [9], [6]], 'infRate': 0.3},
#  223: {'actions': [[3], [6], [8]], 'infRate': 0.3},
#  224: {'actions': [[0], [2], [7]], 'infRate': 0.2},
#  225: {'actions': [[4], [3], [9]], 'infRate': 0.3},
#  226: {'actions': [[4], [0], [7]], 'infRate': 0.1},
#  227: {'actions': [[7], [6], [4]], 'infRate': 0.1},
#  228: {'actions': [[2], [5], [3]], 'infRate': 0.2},
#  229: {'actions': [[8], [6], [3]], 'infRate': 0.3},
#  230: {'actions': [[2], [0], [8]], 'infRate': 0.2},
#  231: {'actions': [[9], [7]], 'infRate': 0.2},
#  232: {'actions': [[9], [6], [0]], 'infRate': 0.3},
#  233: {'actions': [[9], [5]], 'infRate': 0.3},
#  234: {'actions': [[9], [2], [7]], 'infRate': 0.2},
#  235: {'actions': [[5], [2], [4]], 'infRate': 0.1},
#  236: {'actions': [[5], [0], [2]], 'infRate': 0.3},
#  237: {'actions': [[3], [1], [8]], 'infRate': 0.3},
#  238: {'actions': [[0], [8], [5]], 'infRate': 0.3},
#  239: {'actions': [[9], [6], [7]], 'infRate': 0.1},
#  240: {'actions': [[1], [9], [7]], 'infRate': 0.1},
#  241: {'actions': [[6], [9], [4]], 'infRate': 0.3},
#  242: {'actions': [[7], [0]], 'infRate': 0.2},
#  243: {'actions': [[2], [5], [0]], 'infRate': 0.2},
#  244: {'actions': [[6], [9], [1]], 'infRate': 0.3},
#  245: {'actions': [[4], [8], [2]], 'infRate': 0.2},
#  246: {'actions': [[4], [0], [8]], 'infRate': 0.1},
#  247: {'actions': [[4], [9], [2]], 'infRate': 0.3},
#  248: {'actions': [[7], [2], [4]], 'infRate': 0.1},
#  249: {'actions': [[3], [6], [7]], 'infRate': 0.3},
#  250: {'actions': [[5], [3], [2]], 'infRate': 0.3},
#  251: {'actions': [[7], [2], [8]], 'infRate': 0.3},
#  252: {'actions': [[1], [9], [4]], 'infRate': 0.3},
#  253: {'actions': [[4], [7], [2]], 'infRate': 0.2},
#  254: {'actions': [[9], [1], [7]], 'infRate': 0.3},
#  255: {'actions': [[8], [0], [6]], 'infRate': 0.3},
#  256: {'actions': [[2], [6], [4]], 'infRate': 0.1},
#  257: {'actions': [[4], [0], [1]], 'infRate': 0.3},
#  258: {'actions': [[1], [6], [7]], 'infRate': 0.2},
#  259: {'actions': [[4], [2], [7]], 'infRate': 0.1},
#  260: {'actions': [[5], [0], [2]], 'infRate': 0.3},
#  261: {'actions': [[5], [7], [8]], 'infRate': 0.1},
#  262: {'actions': [[7], [1], [8]], 'infRate': 0.2},
#  263: {'actions': [[2], [0], [8]], 'infRate': 0.2},
#  264: {'actions': [[3], [9], [2], [0]], 'infRate': 0.3},
#  265: {'actions': [[7], [4], [6]], 'infRate': 0.1},
#  266: {'actions': [[3], [8], [5]], 'infRate': 0.2},
#  267: {'actions': [[5], [8], [6]], 'infRate': 0.1},
#  268: {'actions': [[3], [0], [8]], 'infRate': 0.2},
#  269: {'actions': [[5], [7], [8]], 'infRate': 0.1},
#  270: {'actions': [[3], [9], [2]], 'infRate': 0.3},
#  271: {'actions': [[4], [2], [0]], 'infRate': 0.2},
#  272: {'actions': [[2], [9], [8]], 'infRate': 0.2},
#  273: {'actions': [[2], [4], [1]], 'infRate': 0.1},
#  274: {'actions': [[4], [8], [6]], 'infRate': 0.3},
#  275: {'actions': [[8], [9], [2]], 'infRate': 0.3},
#  276: {'actions': [[0], [7], [5]], 'infRate': 0.3},
#  277: {'actions': [[9], [8], [5]], 'infRate': 0.1},
#  278: {'actions': [[5], [2], [8]], 'infRate': 0.3},
#  279: {'actions': [[3], [1], [7]], 'infRate': 0.1},
#  280: {'actions': [[4], [7], [6]], 'infRate': 0.1},
#  281: {'actions': [[5], [1], [8]], 'infRate': 0.2},
#  282: {'actions': [[4], [0], [2]], 'infRate': 0.1},
#  283: {'actions': [[0], [3], [2]], 'infRate': 0.2},
#  284: {'actions': [[5], [8], [7]], 'infRate': 0.3},
#  285: {'actions': [[1], [6], [5]], 'infRate': 0.3},
#  286: {'actions': [[0], [2], [8]], 'infRate': 0.1},
#  287: {'actions': [[6], [0], [3]], 'infRate': 0.1},
#  288: {'actions': [[6], [9], [4]], 'infRate': 0.2},
#  289: {'actions': [[3], [7], [1]], 'infRate': 0.3},
#  290: {'actions': [[4], [1], [8]], 'infRate': 0.2},
#  291: {'actions': [[6], [9], [8]], 'infRate': 0.3},
#  292: {'actions': [[8], [5], [2]], 'infRate': 0.1},
#  293: {'actions': [[0], [8], [4]], 'infRate': 0.2},
#  294: {'actions': [[8], [5], [0]], 'infRate': 0.2},
#  295: {'actions': [[3], [6], [9]], 'infRate': 0.3},
#  296: {'actions': [[3], [1], [0]], 'infRate': 0.2},
#  297: {'actions': [[4], [9], [2]], 'infRate': 0.1},
#  298: {'actions': [[9], [5], [7]], 'infRate': 0.1},
#  299: {'actions': [[9], [0], [7]], 'infRate': 0.2},
#  300: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  301: {'actions': [[0], [1], [7]], 'infRate': 0.2},
#  302: {'actions': [[2], [4], [5]], 'infRate': 0.3},
#  303: {'actions': [[3], [5], [6]], 'infRate': 0.1},
#  304: {'actions': [[4], [2], [0]], 'infRate': 0.1},
#  305: {'actions': [[4], [7], [6]], 'infRate': 0.3},
#  306: {'actions': [[7], [0], [4]], 'infRate': 0.3},
#  307: {'actions': [[4], [9], [6]], 'infRate': 0.3},
#  308: {'actions': [[9], [6], [7]], 'infRate': 0.2},
#  309: {'actions': [[9], [2], [7]], 'infRate': 0.2},
#  310: {'actions': [[1], [6], [2]], 'infRate': 0.3},
#  311: {'actions': [[1], [6], [4]], 'infRate': 0.4},
#  312: {'actions': [[3], [6], [4]], 'infRate': 0.2},
#  313: {'actions': [[9], [3], [8]], 'infRate': 0.1},
#  314: {'actions': [[5], [9], [1]], 'infRate': 0.2},
#  315: {'actions': [[3], [5], [0]], 'infRate': 0.3},
#  316: {'actions': [[5], [8], [2]], 'infRate': 0.3},
#  317: {'actions': [[9], [0], [7]], 'infRate': 0.1},
#  318: {'actions': [[3], [0], [8]], 'infRate': 0.3},
#  319: {'actions': [[4], [8], [1]], 'infRate': 0.3},
#  320: {'actions': [[3], [2], [6]], 'infRate': 0.3},
#  321: {'actions': [[9], [0], [2]], 'infRate': 0.1},
#  322: {'actions': [[6], [2], [9]], 'infRate': 0.1},
#  323: {'actions': [[4], [0], [2]], 'infRate': 0.1},
#  324: {'actions': [[1], [4], [7]], 'infRate': 0.2},
#  325: {'actions': [[3], [6], [2]], 'infRate': 0.3},
#  326: {'actions': [[8], [0], [5]], 'infRate': 0.2},
#  327: {'actions': [[3], [5], [9]], 'infRate': 0.2},
#  328: {'actions': [[5], [7], [8]], 'infRate': 0.1},
#  329: {'actions': [[5], [0], [8]], 'infRate': 0.3},
#  330: {'actions': [[3], [5], [2]], 'infRate': 0.2},
#  331: {'actions': [[8], [0], [6]], 'infRate': 0.1},
#  332: {'actions': [[3], [5], [0]], 'infRate': 0.1},
#  333: {'actions': [[4], [6], [2]], 'infRate': 0.3},
#  334: {'actions': [[2], [8], [4]], 'infRate': 0.1},
#  335: {'actions': [[4], [5], [1]], 'infRate': 0.3},
#  336: {'actions': [[3], [6], [4]], 'infRate': 0.3},
#  337: {'actions': [[0], [7], [2]], 'infRate': 0.2},
#  338: {'actions': [[6], [8], [1]], 'infRate': 0.3},
#  339: {'actions': [[5], [1], [4]], 'infRate': 0.3},
#  340: {'actions': [[5], [0], [2]], 'infRate': 0.2},
#  341: {'actions': [[3], [1], [6]], 'infRate': 0.2},
#  342: {'actions': [[9], [6], [4]], 'infRate': 0.1},
#  343: {'actions': [[4], [6], [1]], 'infRate': 0.3},
#  344: {'actions': [[3], [6], [1]], 'infRate': 0.1},
#  345: {'actions': [[5], [9], [1]], 'infRate': 0.2},
#  346: {'actions': [[4], [1], [7]], 'infRate': 0.3},
#  347: {'actions': [[5], [1], [6]], 'infRate': 0.2},
#  348: {'actions': [[1], [8], [3]], 'infRate': 0.2},
#  349: {'actions': [[4], [9], [6]], 'infRate': 0.3},
#  350: {'actions': [[9], [4], [7]], 'infRate': 0.3},
#  351: {'actions': [[0], [8], [6]], 'infRate': 0.1},
#  352: {'actions': [[2], [9], [1]], 'infRate': 0.2},
#  353: {'actions': [[6], [2], [5]], 'infRate': 0.2},
#  354: {'actions': [[1], [3]], 'infRate': 0.3},
#  355: {'actions': [[7], [9], [5]], 'infRate': 0.1},
#  356: {'actions': [[4], [0], [6]], 'infRate': 0.2},
#  357: {'actions': [[4], [3], [9]], 'infRate': 0.1},
#  358: {'actions': [[4], [6], [8]], 'infRate': 0.2},
#  359: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  360: {'actions': [[3], [8], [1]], 'infRate': 0.2},
#  361: {'actions': [[3], [9], [7]], 'infRate': 0.3},
#  362: {'actions': [[2], [6], [7]], 'infRate': 0.1},
#  363: {'actions': [[2], [3], [9]], 'infRate': 0.1},
#  364: {'actions': [[8], [0], [3], [7], [5]], 'infRate': 0.3},
#  365: {'actions': [[1], [3], [7]], 'infRate': 0.3},
#  366: {'actions': [[5], [8], [9]], 'infRate': 0.3},
#  367: {'actions': [[1], [3], [5]], 'infRate': 0.2},
#  368: {'actions': [[2], [6], [3]], 'infRate': 0.1},
#  369: {'actions': [[4], [1], [8]], 'infRate': 0.3},
#  370: {'actions': [[4], [3], [1]], 'infRate': 0.1},
#  371: {'actions': [[0], [2], [4]], 'infRate': 0.3},
#  372: {'actions': [[9], [7], [0]], 'infRate': 0.2},
#  373: {'actions': [[7], [1], [6]], 'infRate': 0.2},
#  374: {'actions': [[9], [2], [7]], 'infRate': 0.1},
#  375: {'actions': [[9], [8], [6]], 'infRate': 0.2},
#  376: {'actions': [[8], [2], [0]], 'infRate': 0.1},
#  377: {'actions': [[1], [6], [7]], 'infRate': 0.2},
#  378: {'actions': [[3], [1], [0]], 'infRate': 0.1},
#  379: {'actions': [[5], [2], [6]], 'infRate': 0.2},
#  380: {'actions': [[0], [8], [5]], 'infRate': 0.3},
#  381: {'actions': [[9], [1], [6]], 'infRate': 0.3},
#  382: {'actions': [[0], [8], [5]], 'infRate': 0.2},
#  383: {'actions': [[6], [8], [3]], 'infRate': 0.2},
#  384: {'actions': [[3], [7], [5]], 'infRate': 0.1},
#  385: {'actions': [[0], [9], [4]], 'infRate': 0.2},
#  386: {'actions': [[6], [0], [7]], 'infRate': 0.2},
#  387: {'actions': [[4], [1], [0]], 'infRate': 0.2},
#  388: {'actions': [[0], [5], [4]], 'infRate': 0.1},
#  389: {'actions': [[5], [7], [4]], 'infRate': 0.3},
#  390: {'actions': [[5], [1], [3]], 'infRate': 0.1},
#  391: {'actions': [[3], [5], [6]], 'infRate': 0.1},
#  392: {'actions': [[9], [4], [7]], 'infRate': 0.2},
#  393: {'actions': [[8], [6], [4]], 'infRate': 0.1},
#  394: {'actions': [[9], [8], [5]], 'infRate': 0.3},
#  395: {'actions': [[5], [0], [7]], 'infRate': 0.2},
#  396: {'actions': [[9], [1], [7]], 'infRate': 0.2},
#  397: {'actions': [[0], [1], [8]], 'infRate': 0.2},
#  398: {'actions': [[1], [8], [3]], 'infRate': 0.1},
#  399: {'actions': [[9], [7], [8]], 'infRate': 0.3},
#  400: {'actions': [[9], [0]], 'infRate': 0.3},
#  401: {'actions': [[0], [7], [8]], 'infRate': 0.2},
#  402: {'actions': [[9], [8], [1]], 'infRate': 0.1},
#  403: {'actions': [[2], [6], [4]], 'infRate': 0.1},
#  404: {'actions': [[9], [5], [1]], 'infRate': 0.3},
#  405: {'actions': [[3], [1], [5]], 'infRate': 0.2},
#  406: {'actions': [[2], [1], [9]], 'infRate': 0.2},
#  407: {'actions': [[7], [2], [0]], 'infRate': 0.3},
#  408: {'actions': [[1], [6], [9]], 'infRate': 0.1},
#  409: {'actions': [[5], [0], [2], [8]], 'infRate': 0.2},
#  410: {'actions': [[3], [6], [7]], 'infRate': 0.2},
#  411: {'actions': [[6], [8], [9]], 'infRate': 0.1},
#  412: {'actions': [[0], [9], [2]], 'infRate': 0.3},
#  413: {'actions': [[0], [5], [7]], 'infRate': 0.2},
#  414: {'actions': [[0], [3], [7]], 'infRate': 0.3},
#  415: {'actions': [[3], [0], [8]], 'infRate': 0.2},
#  416: {'actions': [[5], [9], [7]], 'infRate': 0.3},
#  417: {'actions': [[3], [4], [8]], 'infRate': 0.1},
#  418: {'actions': [[4], [9], [7]], 'infRate': 0.2},
#  419: {'actions': [[7], [0], [5]], 'infRate': 0.4},
#  420: {'actions': [[9], [2], [7]], 'infRate': 0.1},
#  421: {'actions': [[4], [2], [8]], 'infRate': 0.1},
#  422: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  423: {'actions': [[5], [2], [8]], 'infRate': 0.3},
#  424: {'actions': [[3], [5], [6]], 'infRate': 0.1},
#  425: {'actions': [[6], [3], [8]], 'infRate': 0.3},
#  426: {'actions': [[4], [7], [8]], 'infRate': 0.2},
#  427: {'actions': [[4], [9]], 'infRate': 0.3},
#  428: {'actions': [[2], [4], [5]], 'infRate': 0.4},
#  429: {'actions': [[5], [0], [8]], 'infRate': 0.3},
#  430: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  431: {'actions': [[4], [0], [8]], 'infRate': 0.3},
#  432: {'actions': [[9], [0], [6]], 'infRate': 0.3},
#  433: {'actions': [[7], [5], [3]], 'infRate': 0.2},
#  434: {'actions': [[8], [0], [2]], 'infRate': 0.3},
#  435: {'actions': [[8], [0], [2]], 'infRate': 0.2},
#  436: {'actions': [[6], [0], [2]], 'infRate': 0.3},
#  437: {'actions': [[7], [4], [2]], 'infRate': 0.1},
#  438: {'actions': [[3], [0], [5]], 'infRate': 0.2},
#  439: {'actions': [[4], [8], [2]], 'infRate': 0.1},
#  440: {'actions': [[2], [4], [6]], 'infRate': 0.2},
#  441: {'actions': [[7], [6], [4]], 'infRate': 0.3},
#  442: {'actions': [[5], [9], [3]], 'infRate': 0.2},
#  443: {'actions': [[8], [0], [6]], 'infRate': 0.2},
#  444: {'actions': [[0], [1], [7]], 'infRate': 0.1},
#  445: {'actions': [[9], [8], [5]], 'infRate': 0.2},
#  446: {'actions': [[3], [0], [6]], 'infRate': 0.3},
#  447: {'actions': [[4], [8], [2]], 'infRate': 0.2},
#  448: {'actions': [[7], [0], [8]], 'infRate': 0.1},
#  449: {'actions': [[2], [3], [9]], 'infRate': 0.1},
#  450: {'actions': [[8], [3], [5]], 'infRate': 0.2},
#  451: {'actions': [[4], [6], [2]], 'infRate': 0.1},
#  452: {'actions': [[4], [6], [0]], 'infRate': 0.3},
#  453: {'actions': [[5], [7], [9]], 'infRate': 0.3},
#  454: {'actions': [[0], [1], [6]], 'infRate': 0.2},
#  455: {'actions': [[4], [8], [5]], 'infRate': 0.1},
#  456: {'actions': [[3], [0], [5]], 'infRate': 0.1},
#  457: {'actions': [[3], [0], [5]], 'infRate': 0.3},
#  458: {'actions': [[0], [5], [2]], 'infRate': 0.1},
#  459: {'actions': [[6], [1], [4]], 'infRate': 0.2},
#  460: {'actions': [[4], [9], [8]], 'infRate': 0.1},
#  461: {'actions': [[1], [9], [2]], 'infRate': 0.1},
#  462: {'actions': [[0], [8], [1]], 'infRate': 0.1},
#  463: {'actions': [[1], [9], [7]], 'infRate': 0.3},
#  464: {'actions': [[3], [9], [5]], 'infRate': 0.3},
#  465: {'actions': [[3], [4], [1]], 'infRate': 0.3},
#  466: {'actions': [[3], [1], [9]], 'infRate': 0.2},
#  467: {'actions': [[4], [0], [2]], 'infRate': 0.2},
#  468: {'actions': [[6], [3], [7]], 'infRate': 0.2},
#  469: {'actions': [[9], [8], [2]], 'infRate': 0.3},
#  470: {'actions': [[0], [2], [3]], 'infRate': 0.1},
#  471: {'actions': [[0], [7], [4]], 'infRate': 0.2},
#  472: {'actions': [[4], [1], [2]], 'infRate': 0.1},
#  473: {'actions': [[1], [9], [2]], 'infRate': 0.1},
#  474: {'actions': [[6], [4], [2]], 'infRate': 0.2},
#  475: {'actions': [[5], [1], [7]], 'infRate': 0.3},
#  476: {'actions': [[5], [0]], 'infRate': 0.2},
#  477: {'actions': [[9], [1], [3]], 'infRate': 0.2},
#  478: {'actions': [[1], [9], [8]], 'infRate': 0.1},
#  479: {'actions': [[5], [8], [1]], 'infRate': 0.3},
#  480: {'actions': [[9], [4], [6]], 'infRate': 0.2},
#  481: {'actions': [[2], [0], [8]], 'infRate': 0.1},
#  482: {'actions': [[5], [8], [7]], 'infRate': 0.2},
#  483: {'actions': [[0], [8], [2]], 'infRate': 0.3},
#  484: {'actions': [[9], [0], [2]], 'infRate': 0.1},
#  485: {'actions': [[9], [7], [5]], 'infRate': 0.1},
#  486: {'actions': [[2], [6], [8]], 'infRate': 0.1},
#  487: {'actions': [[3], [6], [1]], 'infRate': 0.1},
#  488: {'actions': [[9], [1], [5]], 'infRate': 0.3},
#  489: {'actions': [[0], [8], [1]], 'infRate': 0.1},
#  490: {'actions': [[3], [0], [7]], 'infRate': 0.3},
#  491: {'actions': [[0], [6], [5]], 'infRate': 0.3},
#  492: {'actions': [[5], [3], [1]], 'infRate': 0.2},
#  493: {'actions': [[4], [2], [0]], 'infRate': 0.1},
#  494: {'actions': [[0], [3], [4]], 'infRate': 0.2},
#  495: {'actions': [[2], [3], [5]], 'infRate': 0.1},
#  496: {'actions': [[8], [0], [3]], 'infRate': 0.1},
#  497: {'actions': [[0], [8], [5]], 'infRate': 0.3},
#  498: {'actions': [[0], [8], [7]], 'infRate': 0.2},
#  499: {'actions': [[5], [9], [1]], 'infRate': 0.2},
#  500: {'actions': [[4], [2], [7]], 'infRate': 0.3},
#  501: {'actions': [[3], [1], [7]], 'infRate': 0.2},
#  502: {'actions': [[7], [5], [1]], 'infRate': 0.3},
#  503: {'actions': [[4], [1], [2]], 'infRate': 0.3},
#  504: {'actions': [[5], [9], [7]], 'infRate': 0.3},
#  505: {'actions': [[9], [7]], 'infRate': 0.3},
#  506: {'actions': [[1], [4], [6]], 'infRate': 0.2},
#  507: {'actions': [[9], [5], [0]], 'infRate': 0.3},
#  508: {'actions': [[9], [3], [8]], 'infRate': 0.2},
#  509: {'actions': [[0], [3], [4]], 'infRate': 0.2},
#  510: {'actions': [[6], [2], [8]], 'infRate': 0.2},
#  511: {'actions': [[1], [4], [8]], 'infRate': 0.3},
#  512: {'actions': [[8], [1], [2]], 'infRate': 0.3},
#  513: {'actions': [[6], [2], [4]], 'infRate': 0.2},
#  514: {'actions': [[1], [9], [6]], 'infRate': 0.2},
#  515: {'actions': [[3], [1], [8]], 'infRate': 0.3},
#  516: {'actions': [[6], [0], [4], [2], [8]], 'infRate': 0.4},
#  517: {'actions': [[0], [6], [4]], 'infRate': 0.2},
#  518: {'actions': [[4], [9], [6]], 'infRate': 0.2},
#  519: {'actions': [[7], [1], [3]], 'infRate': 0.3},
#  520: {'actions': [[2], [4], [1]], 'infRate': 0.2},
#  521: {'actions': [[1], [2], [4]], 'infRate': 0.2},
#  522: {'actions': [[0], [7], [4]], 'infRate': 0.2},
#  523: {'actions': [[8], [1], [2]], 'infRate': 0.3},
#  524: {'actions': [[3], [4], [6]], 'infRate': 0.1},
#  525: {'actions': [[0], [2], [5]], 'infRate': 0.1},
#  526: {'actions': [[3], [5], [6]], 'infRate': 0.1},
#  527: {'actions': [[3], [1], [5]], 'infRate': 0.3},
#  528: {'actions': [[8], [5]], 'infRate': 0.4},
#  529: {'actions': [[3], [1], [7]], 'infRate': 0.2},
#  530: {'actions': [[1], [4], [0]], 'infRate': 0.2},
#  531: {'actions': [[3], [8], [6]], 'infRate': 0.2},
#  532: {'actions': [[1], [0], [7]], 'infRate': 0.3},
#  533: {'actions': [[4], [0], [6]], 'infRate': 0.1},
#  534: {'actions': [[8], [5], [7]], 'infRate': 0.1},
#  535: {'actions': [[8], [0], [3], [7]], 'infRate': 0.2},
#  536: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  537: {'actions': [[3], [9], [2]], 'infRate': 0.1},
#  538: {'actions': [[8], [3], [7]], 'infRate': 0.3},
#  539: {'actions': [[5], [4], [0]], 'infRate': 0.1},
#  540: {'actions': [[5], [3], [7]], 'infRate': 0.1},
#  541: {'actions': [[4], [8], [2]], 'infRate': 0.2},
#  542: {'actions': [[2], [0], [8]], 'infRate': 0.2},
#  543: {'actions': [[2], [5], [3]], 'infRate': 0.2},
#  544: {'actions': [[1], [9], [6]], 'infRate': 0.2},
#  545: {'actions': [[4], [2], [7]], 'infRate': 0.3},
#  546: {'actions': [[3], [6], [5]], 'infRate': 0.2},
#  547: {'actions': [[1], [0], [3]], 'infRate': 0.1},
#  548: {'actions': [[2], [4], [0]], 'infRate': 0.2},
#  549: {'actions': [[3], [0], [2]], 'infRate': 0.1},
#  550: {'actions': [[1], [2], [6]], 'infRate': 0.2},
#  551: {'actions': [[3], [0], [2]], 'infRate': 0.3},
#  552: {'actions': [[1], [8], [9]], 'infRate': 0.1},
#  553: {'actions': [[2], [3], [9]], 'infRate': 0.3},
#  554: {'actions': [[7], [6], [4]], 'infRate': 0.1},
#  555: {'actions': [[3], [9], [7]], 'infRate': 0.1},
#  556: {'actions': [[0], [2], [7]], 'infRate': 0.2},
#  557: {'actions': [[0], [1], [6]], 'infRate': 0.2},
#  558: {'actions': [[4], [6], [8]], 'infRate': 0.2},
#  559: {'actions': [[0], [2], [7]], 'infRate': 0.3},
#  560: {'actions': [[3], [9], [1]], 'infRate': 0.2},
#  561: {'actions': [[5], [0], [2]], 'infRate': 0.2},
#  562: {'actions': [[3], [2], [6]], 'infRate': 0.3},
#  563: {'actions': [[2], [4], [1]], 'infRate': 0.1},
#  564: {'actions': [[4], [1], [3]], 'infRate': 0.2},
#  565: {'actions': [[3], [1], [6]], 'infRate': 0.2},
#  566: {'actions': [[6], [3], [8]], 'infRate': 0.3},
#  567: {'actions': [[8], [7], [3]], 'infRate': 0.2},
#  568: {'actions': [[5], [0], [8]], 'infRate': 0.3},
#  569: {'actions': [[9], [0], [2]], 'infRate': 0.2},
#  570: {'actions': [[5], [6], [8]], 'infRate': 0.2},
#  571: {'actions': [[2], [9], [6]], 'infRate': 0.3},
#  572: {'actions': [[1], [8], [7]], 'infRate': 0.3},
#  573: {'actions': [[3], [9], [5]], 'infRate': 0.2},
#  574: {'actions': [[4], [0], [6]], 'infRate': 0.3},
#  575: {'actions': [[1], [2], [8]], 'infRate': 0.1},
#  576: {'actions': [[1], [9], [8]], 'infRate': 0.3},
#  577: {'actions': [[0], [5], [1]], 'infRate': 0.3},
#  578: {'actions': [[7], [1], [2]], 'infRate': 0.1},
#  579: {'actions': [[5], [1], [2]], 'infRate': 0.3},
#  580: {'actions': [[4], [3], [8]], 'infRate': 0.1},
#  581: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  582: {'actions': [[4], [0], [5]], 'infRate': 0.3},
#  583: {'actions': [[5], [9], [7]], 'infRate': 0.2},
#  584: {'actions': [[9], [6], [7]], 'infRate': 0.1},
#  585: {'actions': [[2], [6], [0]], 'infRate': 0.2},
#  586: {'actions': [[3], [8], [2]], 'infRate': 0.1},
#  587: {'actions': [[5], [9], [7]], 'infRate': 0.1},
#  588: {'actions': [[1], [8], [7]], 'infRate': 0.1},
#  589: {'actions': [[9], [1], [8]], 'infRate': 0.1},
#  590: {'actions': [[8], [1], [4]], 'infRate': 0.3},
#  591: {'actions': [[2], [8], [3]], 'infRate': 0.3},
#  592: {'actions': [[6], [0], [3]], 'infRate': 0.1},
#  593: {'actions': [[3], [5], [6]], 'infRate': 0.1},
#  594: {'actions': [[5], [7], [1]], 'infRate': 0.3},
#  595: {'actions': [[6], [2], [0]], 'infRate': 0.1},
#  596: {'actions': [[5], [7], [1]], 'infRate': 0.4},
#  597: {'actions': [[9], [5], [0]], 'infRate': 0.1},
#  598: {'actions': [[9], [0], [2], [6]], 'infRate': 0.3},
#  599: {'actions': [[3], [1], [8]], 'infRate': 0.1},
#  600: {'actions': [[8], [5], [1]], 'infRate': 0.2},
#  601: {'actions': [[9], [3], [2]], 'infRate': 0.1},
#  602: {'actions': [[2], [6], [3]], 'infRate': 0.4},
#  603: {'actions': [[9], [2], [4]], 'infRate': 0.1},
#  604: {'actions': [[3], [4], [6]], 'infRate': 0.2},
#  605: {'actions': [[0], [9], [7]], 'infRate': 0.1},
#  606: {'actions': [[4], [7]], 'infRate': 0.4},
#  607: {'actions': [[1], [9], [7]], 'infRate': 0.1},
#  608: {'actions': [[9], [6], [1], [5]], 'infRate': 0.4},
#  609: {'actions': [[5], [0], [3]], 'infRate': 0.2},
#  610: {'actions': [[1], [2], [9]], 'infRate': 0.1},
#  611: {'actions': [[0], [2], [8]], 'infRate': 0.3},
#  612: {'actions': [[1], [6]], 'infRate': 0.2},
#  613: {'actions': [[9], [2], [4]], 'infRate': 0.2},
#  614: {'actions': [[3], [7], [2]], 'infRate': 0.3},
#  615: {'actions': [[3], [9], [1]], 'infRate': 0.3},
#  616: {'actions': [[9], [4], [7]], 'infRate': 0.3},
#  617: {'actions': [[0], [8], [4]], 'infRate': 0.1},
#  618: {'actions': [[8], [0], [7]], 'infRate': 0.2},
#  619: {'actions': [[9], [0], [2]], 'infRate': 0.2},
#  620: {'actions': [[1], [9], [7]], 'infRate': 0.1},
#  621: {'actions': [[3], [0], [7]], 'infRate': 0.1},
#  622: {'actions': [[0], [2], [8]], 'infRate': 0.3},
#  623: {'actions': [[1], [9], [7]], 'infRate': 0.2},
#  624: {'actions': [[3], [1], [7]], 'infRate': 0.2},
#  625: {'actions': [[7], [2], [4]], 'infRate': 0.1},
#  626: {'actions': [[8], [3], [0]], 'infRate': 0.2},
#  627: {'actions': [[0], [7], [5]], 'infRate': 0.3},
#  628: {'actions': [[9], [1], [5]], 'infRate': 0.1},
#  629: {'actions': [[3], [9], [5]], 'infRate': 0.1},
#  630: {'actions': [[6], [7], [9], [0]], 'infRate': 0.4},
#  631: {'actions': [[0], [6], [8]], 'infRate': 0.1},
#  632: {'actions': [[4], [9], [6]], 'infRate': 0.3},
#  633: {'actions': [[0], [4], [8]], 'infRate': 0.2},
#  634: {'actions': [[5], [0], [7]], 'infRate': 0.1},
#  635: {'actions': [[0], [4], [2]], 'infRate': 0.3},
#  636: {'actions': [[3], [0], [5]], 'infRate': 0.1},
#  637: {'actions': [[4], [8], [7]], 'infRate': 0.2},
#  638: {'actions': [[9], [0], [7]], 'infRate': 0.1},
#  639: {'actions': [[3], [0], [6]], 'infRate': 0.3},
#  640: {'actions': [[5], [0], [7]], 'infRate': 0.1},
#  641: {'actions': [[4], [3], [7]], 'infRate': 0.3},
#  642: {'actions': [[0], [9], [7]], 'infRate': 0.3},
#  643: {'actions': [[7], [2], [6]], 'infRate': 0.2},
#  644: {'actions': [[3], [5], [9]], 'infRate': 0.3},
#  645: {'actions': [[4], [8], [1]], 'infRate': 0.3},
#  646: {'actions': [[9], [1], [6]], 'infRate': 0.1},
#  647: {'actions': [[2], [6], [8]], 'infRate': 0.2},
#  648: {'actions': [[0], [7], [3]], 'infRate': 0.3},
#  649: {'actions': [[5], [3], [1]], 'infRate': 0.3},
#  650: {'actions': [[2], [0], [7]], 'infRate': 0.1},
#  651: {'actions': [[5], [3], [0]], 'infRate': 0.3},
#  652: {'actions': [[9], [6], [4]], 'infRate': 0.3},
#  653: {'actions': [[7], [2], [5]], 'infRate': 0.3},
#  654: {'actions': [[4], [7], [9]], 'infRate': 0.2},
#  655: {'actions': [[4], [3], [1]], 'infRate': 0.2},
#  656: {'actions': [[3], [9], [1]], 'infRate': 0.3},
#  657: {'actions': [[4], [1], [7]], 'infRate': 0.2},
#  658: {'actions': [[2], [6], [4]], 'infRate': 0.2},
#  659: {'actions': [[2], [6], [1]], 'infRate': 0.1},
#  660: {'actions': [[4], [7], [2]], 'infRate': 0.3},
#  661: {'actions': [[5], [9], [0]], 'infRate': 0.1},
#  662: {'actions': [[0], [4], [6]], 'infRate': 0.2},
#  663: {'actions': [[6], [9], [7]], 'infRate': 0.3},
#  664: {'actions': [[2], [9], [6]], 'infRate': 0.1},
#  665: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  666: {'actions': [[4], [7], [1]], 'infRate': 0.3},
#  667: {'actions': [[3], [0], [6]], 'infRate': 0.3},
#  668: {'actions': [[3], [0], [7]], 'infRate': 0.2},
#  669: {'actions': [[3], [1], [4]], 'infRate': 0.2},
#  670: {'actions': [[3], [6], [0]], 'infRate': 0.3},
#  671: {'actions': [[4], [8], [3]], 'infRate': 0.1},
#  672: {'actions': [[5], [4], [2]], 'infRate': 0.2},
#  673: {'actions': [[3], [1], [5]], 'infRate': 0.2},
#  674: {'actions': [[2], [4], [6]], 'infRate': 0.3},
#  675: {'actions': [[8], [2], [0]], 'infRate': 0.2},
#  676: {'actions': [[4], [9], [8]], 'infRate': 0.2},
#  677: {'actions': [[3], [5], [0]], 'infRate': 0.2},
#  678: {'actions': [[9], [1], [4]], 'infRate': 0.2},
#  679: {'actions': [[1], [6], [5]], 'infRate': 0.3},
#  680: {'actions': [[5], [0], [8]], 'infRate': 0.2},
#  681: {'actions': [[5], [8], [7]], 'infRate': 0.3},
#  682: {'actions': [[9], [1], [6]], 'infRate': 0.1},
#  683: {'actions': [[0], [4], [7]], 'infRate': 0.3},
#  684: {'actions': [[0], [7], [5]], 'infRate': 0.1},
#  685: {'actions': [[0], [6], [7]], 'infRate': 0.2},
#  686: {'actions': [[9], [4], [5]], 'infRate': 0.3},
#  687: {'actions': [[5], [1], [7]], 'infRate': 0.1},
#  688: {'actions': [[0], [1]], 'infRate': 0.4},
#  689: {'actions': [[1], [6], [0]], 'infRate': 0.2},
#  690: {'actions': [[9], [7], [4]], 'infRate': 0.3},
#  691: {'actions': [[2], [6], [0]], 'infRate': 0.3},
#  692: {'actions': [[7], [2], [0]], 'infRate': 0.2},
#  693: {'actions': [[1], [5], [8]], 'infRate': 0.3},
#  694: {'actions': [[3], [5], [9]], 'infRate': 0.1},
#  695: {'actions': [[4], [5], [2]], 'infRate': 0.3},
#  696: {'actions': [[9], [3], [7]], 'infRate': 0.1},
#  697: {'actions': [[6], [7], [1]], 'infRate': 0.3},
#  698: {'actions': [[3], [8], [5]], 'infRate': 0.3},
#  699: {'actions': [[0], [2], [6]], 'infRate': 0.2},
#  700: {'actions': [[4], [6], [1]], 'infRate': 0.3},
#  701: {'actions': [[9], [5], [2]], 'infRate': 0.1},
#  702: {'actions': [[5], [9], [6]], 'infRate': 0.2},
#  703: {'actions': [[7], [1], [4]], 'infRate': 0.3},
#  704: {'actions': [[6], [7], [1]], 'infRate': 0.2},
#  705: {'actions': [[4], [6], [1]], 'infRate': 0.3},
#  706: {'actions': [[4], [1], [7]], 'infRate': 0.3},
#  707: {'actions': [[2], [6], [1]], 'infRate': 0.1},
#  708: {'actions': [[9], [2], [1]], 'infRate': 0.1},
#  709: {'actions': [[3], [6], [5]], 'infRate': 0.1},
#  710: {'actions': [[3], [5], [7]], 'infRate': 0.3},
#  711: {'actions': [[8], [6], [2]], 'infRate': 0.1},
#  712: {'actions': [[1], [7], [6]], 'infRate': 0.1},
#  713: {'actions': [[3], [6], [7]], 'infRate': 0.2},
#  714: {'actions': [[5], [3], [8]], 'infRate': 0.3},
#  715: {'actions': [[5], [7], [2]], 'infRate': 0.2},
#  716: {'actions': [[9], [1], [6]], 'infRate': 0.1},
#  717: {'actions': [[3], [8], [7]], 'infRate': 0.1},
#  718: {'actions': [[2], [6], [8]], 'infRate': 0.1},
#  719: {'actions': [[1], [3], [9]], 'infRate': 0.3},
#  720: {'actions': [[4], [2], [5]], 'infRate': 0.2},
#  721: {'actions': [[0], [7], [2]], 'infRate': 0.2},
#  722: {'actions': [[3], [2], [6]], 'infRate': 0.1},
#  723: {'actions': [[5], [8], [7]], 'infRate': 0.1},
#  724: {'actions': [[9], [3], [4]], 'infRate': 0.2},
#  725: {'actions': [[4], [0], [2]], 'infRate': 0.1},
#  726: {'actions': [[3], [7], [8]], 'infRate': 0.3},
#  727: {'actions': [[0], [5], [2]], 'infRate': 0.1},
#  728: {'actions': [[7], [5], [9]], 'infRate': 0.3},
#  729: {'actions': [[5], [0], [6]], 'infRate': 0.2},
#  730: {'actions': [[4], [6], [2]], 'infRate': 0.2},
#  731: {'actions': [[9], [7], [2]], 'infRate': 0.3},
#  732: {'actions': [[0], [8], [2]], 'infRate': 0.3},
#  733: {'actions': [[1], [5], [7]], 'infRate': 0.2},
#  734: {'actions': [[5], [0], [7]], 'infRate': 0.2},
#  735: {'actions': [[7], [1], [0]], 'infRate': 0.1},
#  736: {'actions': [[5], [1], [9]], 'infRate': 0.2},
#  737: {'actions': [[3], [7], [4]], 'infRate': 0.2},
#  738: {'actions': [[1], [7], [2]], 'infRate': 0.2},
#  739: {'actions': [[9], [0], [2]], 'infRate': 0.1},
#  740: {'actions': [[9], [1], [4]], 'infRate': 0.1},
#  741: {'actions': [[1], [3], [5]], 'infRate': 0.1},
#  742: {'actions': [[4], [5], [7]], 'infRate': 0.1},
#  743: {'actions': [[0], [8], [9]], 'infRate': 0.1},
#  744: {'actions': [[5], [3], [2]], 'infRate': 0.1},
#  745: {'actions': [[6], [8], [4]], 'infRate': 0.1},
#  746: {'actions': [[3], [0], [8]], 'infRate': 0.3},
#  747: {'actions': [[6], [1], [8]], 'infRate': 0.2},
#  748: {'actions': [[1], [8], [5]], 'infRate': 0.1},
#  749: {'actions': [[4], [6], [5]], 'infRate': 0.2},
#  750: {'actions': [[7], [4], [9]], 'infRate': 0.4},
#  751: {'actions': [[4], [8], [2]], 'infRate': 0.3},
#  752: {'actions': [[4], [2], [7]], 'infRate': 0.2},
#  753: {'actions': [[6], [8], [9]], 'infRate': 0.3},
#  754: {'actions': [[3], [1], [6]], 'infRate': 0.1},
#  755: {'actions': [[7], [4], [2]], 'infRate': 0.3},
#  756: {'actions': [[7], [1], [5]], 'infRate': 0.2},
#  757: {'actions': [[4], [1], [7]], 'infRate': 0.3},
#  758: {'actions': [[6], [4], [2]], 'infRate': 0.3},
#  759: {'actions': [[3], [8], [6]], 'infRate': 0.2},
#  760: {'actions': [[6], [2], [9]], 'infRate': 0.3},
#  761: {'actions': [[2], [8], [7]], 'infRate': 0.2},
#  762: {'actions': [[4], [6], [1]], 'infRate': 0.2},
#  763: {'actions': [[4], [0], [8]], 'infRate': 0.2},
#  764: {'actions': [[6], [8], [4]], 'infRate': 0.2},
#  765: {'actions': [[0], [4], [2]], 'infRate': 0.3},
#  766: {'actions': [[6], [1], [8]], 'infRate': 0.2},
#  767: {'actions': [[9], [1], [3]], 'infRate': 0.1},
#  768: {'actions': [[3], [9], [2]], 'infRate': 0.2},
#  769: {'actions': [[5], [2], [7]], 'infRate': 0.2},
#  770: {'actions': [[3], [0], [4]], 'infRate': 0.2},
#  771: {'actions': [[9], [1], [6]], 'infRate': 0.3},
#  772: {'actions': [[5], [3], [7]], 'infRate': 0.1},
#  773: {'actions': [[6], [1], [8]], 'infRate': 0.3},
#  774: {'actions': [[8], [0], [3]], 'infRate': 0.1},
#  775: {'actions': [[6], [1], [3]], 'infRate': 0.2},
#  776: {'actions': [[5], [1], [6]], 'infRate': 0.3},
#  777: {'actions': [[8], [7], [0]], 'infRate': 0.1},
#  778: {'actions': [[3], [6], [7]], 'infRate': 0.3},
#  779: {'actions': [[9], [1], [7]], 'infRate': 0.1},
#  780: {'actions': [[3], [4], [8]], 'infRate': 0.2},
#  781: {'actions': [[9], [7], [6]], 'infRate': 0.4},
#  782: {'actions': [[9], [0], [3]], 'infRate': 0.2},
#  783: {'actions': [[2], [9], [0]], 'infRate': 0.2},
#  784: {'actions': [[5], [9], [1]], 'infRate': 0.3},
#  785: {'actions': [[4], [3], [7]], 'infRate': 0.3},
#  786: {'actions': [[0], [4], [6]], 'infRate': 0.1},
#  787: {'actions': [[3], [1], [5]], 'infRate': 0.1},
#  788: {'actions': [[1], [9], [6]], 'infRate': 0.1},
#  789: {'actions': [[2], [7], [4]], 'infRate': 0.2},
#  790: {'actions': [[3], [9], [5]], 'infRate': 0.2},
#  791: {'actions': [[9], [1], [2]], 'infRate': 0.2},
#  792: {'actions': [[8], [9], [4]], 'infRate': 0.3},
#  793: {'actions': [[4], [8], [7]], 'infRate': 0.1},
#  794: {'actions': [[3], [7], [2]], 'infRate': 0.3},
#  795: {'actions': [[3], [4], [1]], 'infRate': 0.1},
#  796: {'actions': [[9], [2], [8]], 'infRate': 0.1},
#  797: {'actions': [[0], [2], [9]], 'infRate': 0.1},
#  798: {'actions': [[0], [1], [8]], 'infRate': 0.2},
#  799: {'actions': [[4], [5], [2]], 'infRate': 0.1},
#  800: {'actions': [[0], [5], [2]], 'infRate': 0.2},
#  801: {'actions': [[3], [1], [0]], 'infRate': 0.1},
#  802: {'actions': [[6], [8], [1]], 'infRate': 0.1},
#  803: {'actions': [[6], [4], [9]], 'infRate': 0.3},
#  804: {'actions': [[9], [0], [7]], 'infRate': 0.1},
#  805: {'actions': [[6], [1]], 'infRate': 0.2},
#  806: {'actions': [[6], [9], [7]], 'infRate': 0.2},
#  807: {'actions': [[0], [7], [8]], 'infRate': 0.2},
#  808: {'actions': [[4], [2], [6]], 'infRate': 0.3},
#  809: {'actions': [[6], [0], [8]], 'infRate': 0.3},
#  810: {'actions': [[4], [0], [8]], 'infRate': 0.2},
#  811: {'actions': [[3], [9], [8]], 'infRate': 0.2},
#  812: {'actions': [[9], [1], [2]], 'infRate': 0.1},
#  813: {'actions': [[4], [9], [6]], 'infRate': 0.2},
#  814: {'actions': [[3], [1], [8]], 'infRate': 0.1},
#  815: {'actions': [[4], [0], [6]], 'infRate': 0.3},
#  816: {'actions': [[1], [8], [0]], 'infRate': 0.3},
#  817: {'actions': [[0], [5], [8]], 'infRate': 0.3},
#  818: {'actions': [[4], [6], [2]], 'infRate': 0.1},
#  819: {'actions': [[3], [1], [6]], 'infRate': 0.1},
#  820: {'actions': [[1], [7], [2]], 'infRate': 0.1},
#  821: {'actions': [[3], [9], [5]], 'infRate': 0.3},
#  822: {'actions': [[3], [0]], 'infRate': 0.3},
#  823: {'actions': [[3], [7], [5]], 'infRate': 0.3},
#  824: {'actions': [[2], [6], [4]], 'infRate': 0.3},
#  825: {'actions': [[7], [0], [6]], 'infRate': 0.4},
#  826: {'actions': [[6], [8], [1]], 'infRate': 0.3},
#  827: {'actions': [[1], [9], [2]], 'infRate': 0.2},
#  828: {'actions': [[7], [0], [6]], 'infRate': 0.2},
#  829: {'actions': [[0], [6], [7]], 'infRate': 0.4},
#  830: {'actions': [[8], [0], [3]], 'infRate': 0.1},
#  831: {'actions': [[6], [8], [2]], 'infRate': 0.4},
#  832: {'actions': [[1], [9], [3], [6]], 'infRate': 0.4},
#  833: {'actions': [[8], [9], [2]], 'infRate': 0.3},
#  834: {'actions': [[4], [2], [3]], 'infRate': 0.1},
#  835: {'actions': [[4], [8], [2]], 'infRate': 0.2},
#  836: {'actions': [[2], [6], [8]], 'infRate': 0.1},
#  837: {'actions': [[2], [1], [5]], 'infRate': 0.3},
#  838: {'actions': [[0], [6], [8]], 'infRate': 0.2},
#  839: {'actions': [[4], [6], [1], [8]], 'infRate': 0.3},
#  840: {'actions': [[9], [1], [5]], 'infRate': 0.1},
#  841: {'actions': [[7], [4], [2]], 'infRate': 0.3},
#  842: {'actions': [[4], [8], [9]], 'infRate': 0.3},
#  843: {'actions': [[0], [6], [7]], 'infRate': 0.3},
#  844: {'actions': [[3], [1], [8]], 'infRate': 0.2},
#  845: {'actions': [[3], [9], [5]], 'infRate': 0.2},
#  846: {'actions': [[0], [2], [4]], 'infRate': 0.3},
#  847: {'actions': [[9], [1], [7]], 'infRate': 0.2},
#  848: {'actions': [[4], [7], [1]], 'infRate': 0.2},
#  849: {'actions': [[3], [6], [5]], 'infRate': 0.2},
#  850: {'actions': [[3], [1], [9]], 'infRate': 0.1},
#  851: {'actions': [[0], [7], [5]], 'infRate': 0.3},
#  852: {'actions': [[1], [3], [7]], 'infRate': 0.3},
#  853: {'actions': [[3], [1], [5]], 'infRate': 0.1},
#  854: {'actions': [[4], [0], [2]], 'infRate': 0.2},
#  855: {'actions': [[5], [0], [3]], 'infRate': 0.3},
#  856: {'actions': [[9], [2], [4]], 'infRate': 0.3},
#  857: {'actions': [[9], [3], [1]], 'infRate': 0.1},
#  858: {'actions': [[5], [6], [7]], 'infRate': 0.2},
#  859: {'actions': [[4], [0], [5]], 'infRate': 0.2},
#  860: {'actions': [[0], [8], [4]], 'infRate': 0.3},
#  861: {'actions': [[7], [8], [0]], 'infRate': 0.3},
#  862: {'actions': [[8], [9], [2]], 'infRate': 0.1},
#  863: {'actions': [[3], [1], [5]], 'infRate': 0.1},
#  864: {'actions': [[6], [1], [8]], 'infRate': 0.2},
#  865: {'actions': [[2], [6], [9]], 'infRate': 0.1},
#  866: {'actions': [[4], [2], [6]], 'infRate': 0.1},
#  867: {'actions': [[0], [3], [8]], 'infRate': 0.1},
#  868: {'actions': [[1], [3], [5]], 'infRate': 0.2},
#  869: {'actions': [[2], [3], [7]], 'infRate': 0.2},
#  870: {'actions': [[0], [6], [2]], 'infRate': 0.3},
#  871: {'actions': [[5], [8]], 'infRate': 0.2},
#  872: {'actions': [[5], [3], [2]], 'infRate': 0.1},
#  873: {'actions': [[9], [1], [7]], 'infRate': 0.2},
#  874: {'actions': [[3], [0], [1]], 'infRate': 0.1},
#  875: {'actions': [[2], [3], [1]], 'infRate': 0.3},
#  876: {'actions': [[9], [7], [0]], 'infRate': 0.1},
#  877: {'actions': [[7], [2], [4]], 'infRate': 0.3},
#  878: {'actions': [[8], [4], [3]], 'infRate': 0.2},
#  879: {'actions': [[4], [7], [3]], 'infRate': 0.2},
#  880: {'actions': [[1], [8], [5]], 'infRate': 0.1},
#  881: {'actions': [[2], [9], [3]], 'infRate': 0.3},
#  882: {'actions': [[3], [5], [6]], 'infRate': 0.3},
#  883: {'actions': [[4], [7], [9]], 'infRate': 0.3},
#  884: {'actions': [[2], [8], [1]], 'infRate': 0.3},
#  885: {'actions': [[9], [7], [5]], 'infRate': 0.1},
#  886: {'actions': [[0], [2], [7]], 'infRate': 0.2},
#  887: {'actions': [[5], [7], [8]], 'infRate': 0.3},
#  888: {'actions': [[0], [8], [2]], 'infRate': 0.2},
#  889: {'actions': [[2], [9], [4]], 'infRate': 0.1},
#  890: {'actions': [[8], [7], [5]], 'infRate': 0.2},
#  891: {'actions': [[5], [0], [8]], 'infRate': 0.3},
#  892: {'actions': [[4], [9], [7]], 'infRate': 0.3},
#  893: {'actions': [[6], [0], [8]], 'infRate': 0.1},
#  894: {'actions': [[4], [7], [6]], 'infRate': 0.1},
#  895: {'actions': [[1], [5], [9], [7]], 'infRate': 0.4},
#  896: {'actions': [[8], [0], [2]], 'infRate': 0.1},
#  897: {'actions': [[0], [6], [8]], 'infRate': 0.2},
#  898: {'actions': [[3], [1], [4]], 'infRate': 0.2},
#  899: {'actions': [[6], [0], [8]], 'infRate': 0.3},
#  900: {'actions': [[4], [3], [8]], 'infRate': 0.1},
#  901: {'actions': [[6], [5], [9]], 'infRate': 0.2},
#  902: {'actions': [[3], [0]], 'infRate': 0.4},
#  903: {'actions': [[5], [9], [7]], 'infRate': 0.3},
#  904: {'actions': [[3], [7], [4]], 'infRate': 0.1},
#  905: {'actions': [[4], [9], [5]], 'infRate': 0.1},
#  906: {'actions': [[5], [0], [9]], 'infRate': 0.1},
#  907: {'actions': [[4], [1], [6]], 'infRate': 0.2},
#  908: {'actions': [[4], [6], [0]], 'infRate': 0.1},
#  909: {'actions': [[4], [8], [9]], 'infRate': 0.3},
#  910: {'actions': [[4], [9], [8]], 'infRate': 0.3},
#  911: {'actions': [[9], [6], [7]], 'infRate': 0.1},
#  912: {'actions': [[0], [6], [2]], 'infRate': 0.3},
#  913: {'actions': [[3], [2], [6]], 'infRate': 0.2},
#  914: {'actions': [[9], [8], [2]], 'infRate': 0.2},
#  915: {'actions': [[2], [1], [9]], 'infRate': 0.1},
#  916: {'actions': [[6], [0], [4]], 'infRate': 0.2},
#  917: {'actions': [[9], [2], [6]], 'infRate': 0.2},
#  918: {'actions': [[3], [1], [7]], 'infRate': 0.3},
#  919: {'actions': [[5], [7], [2]], 'infRate': 0.3},
#  920: {'actions': [[3], [6], [1]], 'infRate': 0.3},
#  921: {'actions': [[7], [9], [3]], 'infRate': 0.2},
#  922: {'actions': [[3], [0], [1]], 'infRate': 0.2},
#  923: {'actions': [[0], [8], [4]], 'infRate': 0.2},
#  924: {'actions': [[2], [1], [7]], 'infRate': 0.2},
#  925: {'actions': [[5], [6], [8]], 'infRate': 0.1},
#  926: {'actions': [[1], [9], [2]], 'infRate': 0.1},
#  927: {'actions': [[8], [2], [5]], 'infRate': 0.3},
#  928: {'actions': [[3], [6], [9]], 'infRate': 0.2},
#  929: {'actions': [[5], [9], [7]], 'infRate': 0.3},
#  930: {'actions': [[5], [4], [8]], 'infRate': 0.1},
#  931: {'actions': [[4], [0], [6]], 'infRate': 0.2},
#  932: {'actions': [[4], [1], [3]], 'infRate': 0.1},
#  933: {'actions': [[8], [7], [2]], 'infRate': 0.1},
#  934: {'actions': [[9], [6], [1]], 'infRate': 0.3},
#  935: {'actions': [[4], [2], [1]], 'infRate': 0.2},
#  936: {'actions': [[4], [3], [7]], 'infRate': 0.2},
#  937: {'actions': [[5], [7]], 'infRate': 0.4},
#  938: {'actions': [[6], [9], [4]], 'infRate': 0.3},
#  939: {'actions': [[4], [0], [6]], 'infRate': 0.2},
#  940: {'actions': [[0], [1], [8]], 'infRate': 0.1},
#  941: {'actions': [[3], [6], [8]], 'infRate': 0.1},
#  942: {'actions': [[1], [4], [8]], 'infRate': 0.1},
#  943: {'actions': [[1], [5], [9]], 'infRate': 0.3},
#  944: {'actions': [[6], [1], [4]], 'infRate': 0.2},
#  945: {'actions': [[1], [8], [9]], 'infRate': 0.1},
#  946: {'actions': [[5], [7], [2]], 'infRate': 0.1},
#  947: {'actions': [[8], [0], [6]], 'infRate': 0.3},
#  948: {'actions': [[5], [9], [2]], 'infRate': 0.1},
#  949: {'actions': [[6], [8], [2]], 'infRate': 0.3},
#  950: {'actions': [[2], [6], [4]], 'infRate': 0.2},
#  951: {'actions': [[9], [5], [7]], 'infRate': 0.1},
#  952: {'actions': [[6], [1], [9]], 'infRate': 0.2},
#  953: {'actions': [[3], [6], [5]], 'infRate': 0.1},
#  954: {'actions': [[2], [0], [8]], 'infRate': 0.2},
#  955: {'actions': [[4], [5], [0]], 'infRate': 0.1},
#  956: {'actions': [[4], [6], [9]], 'infRate': 0.1},
#  957: {'actions': [[0], [4], [6]], 'infRate': 0.3},
#  958: {'actions': [[3], [6], [8]], 'infRate': 0.2},
#  959: {'actions': [[9], [2], [0]], 'infRate': 0.1},
#  960: {'actions': [[0], [8], [2]], 'infRate': 0.2},
#  961: {'actions': [[9], [7], [5]], 'infRate': 0.1},
#  962: {'actions': [[1], [6], [4]], 'infRate': 0.3},
#  963: {'actions': [[6], [8], [4]], 'infRate': 0.2},
#  964: {'actions': [[3], [0], [7]], 'infRate': 0.3},
#  965: {'actions': [[7], [2], [4]], 'infRate': 0.3},
#  966: {'actions': [[4], [0], [5]], 'infRate': 0.4},
#  967: {'actions': [[2], [6], [9]], 'infRate': 0.3},
#  968: {'actions': [[2], [7], [5]], 'infRate': 0.3},
#  969: {'actions': [[5], [1], [8]], 'infRate': 0.2},
#  970: {'actions': [[0], [7], [2]], 'infRate': 0.3},
#  971: {'actions': [[0], [7], [4]], 'infRate': 0.3},
#  972: {'actions': [[5], [7], [0], [2]], 'infRate': 0.3},
#  973: {'actions': [[9], [6], [3]], 'infRate': 0.3},
#  974: {'actions': [[0], [9], [3]], 'infRate': 0.2},
#  975: {'actions': [[2], [1], [5]], 'infRate': 0.2},
#  976: {'actions': [[3], [6], [8]], 'infRate': 0.1},
#  977: {'actions': [[0], [4], [8]], 'infRate': 0.3},
#  978: {'actions': [[1], [0], [6]], 'infRate': 0.2},
#  979: {'actions': [[8], [9], [4]], 'infRate': 0.3},
#  980: {'actions': [[6], [9], [7]], 'infRate': 0.1},
#  981: {'actions': [[3], [5], [1]], 'infRate': 0.2},
#  982: {'actions': [[3], [2], [5]], 'infRate': 0.1},
#  983: {'actions': [[5], [3], [7]], 'infRate': 0.1},
#  984: {'actions': [[8], [0], [3]], 'infRate': 0.3},
#  985: {'actions': [[8], [0], [6]], 'infRate': 0.3},
#  986: {'actions': [[4], [9], [7]], 'infRate': 0.1},
#  987: {'actions': [[6], [4], [8]], 'infRate': 0.1},
#  988: {'actions': [[8], [5], [4]], 'infRate': 0.2},
#  989: {'actions': [[7], [3], [9]], 'infRate': 0.3},
#  990: {'actions': [[8], [2], [9]], 'infRate': 0.1},
#  991: {'actions': [[4], [7], [3]], 'infRate': 0.2},
#  992: {'actions': [[9], [6], [4]], 'infRate': 0.1},
#  993: {'actions': [[0], [8], [1]], 'infRate': 0.2},
#  994: {'actions': [[0], [9], [6]], 'infRate': 0.1},
#  995: {'actions': [[2], [6], [8]], 'infRate': 0.1},
#  996: {'actions': [[9], [5], [2]], 'infRate': 0.2},
#  997: {'actions': [[0], [7], [2]], 'infRate': 0.3},
#  998: {'actions': [[3], [5], [7]], 'infRate': 0.1},
#  999: {'actions': [[2], [6], [7]], 'infRate': 0.1}}

# %%
for key, item in actions_dict.items():
    actions_dict[key]['actions'] = [action_item[0] for action_item in item['actions']]

# %%
import json

# save actions dict as json file with intend

with open("actions_r3.json", "w") as outfile: 
    json.dump(actions_dict, outfile, indent=4)
